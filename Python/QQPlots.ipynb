# %% [markdown]
# # Opgave 8.37a

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

data = [2216, 2237, 2249, 2204, 2225, 2301, 2281, 2263, 2318, 2255]

# Calculate theoretical quantiles and sorted values without auto-plotting
(z_scores, values), (slope, intercept, _) = stats.probplot(data, dist="norm")

# Create plot with values on X and z-scores on Y
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(values, z_scores, color="blue", edgecolors="k", label="Data Points")

# Recalculate reference line equation for inverted axes
fit_line_y = (values - intercept) / slope
ax.plot(values, fit_line_y, color="red", linestyle="--", label="Fit Line")

ax.set_xlabel("Values")
ax.set_ylabel("Quantiles (Z-Scores)")
ax.set_title("Normality Plot (8.37a)")
ax.grid(True, linestyle=":", alpha=0.6)
# ax.legend()

plt.tight_layout()
# plt.show()
plt.savefig("opg8.37a.png")

# %% [markdown]
# # Opgave 8.39 a

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

data = [3.775302, 3.350679, 4.217981, 4.030324, 4.639692, 4.139665, 4.395575, 4.824257, 4.268119, 4.584193, 4.930027, 4.315973, 4.600101]

# Calculate theoretical quantiles and sorted values without auto-plotting
(z_scores, values), (slope, intercept, _) = stats.probplot(data, dist="norm")

# Create plot with values on X and z-scores on Y
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(values, z_scores, color="blue", edgecolors="k", label="Data Points")

# Recalculate reference line equation for inverted axes
fit_line_y = (values - intercept) / slope
ax.plot(values, fit_line_y, color="red", linestyle="--", label="Fit Line")

ax.set_xlabel("Values")
ax.set_ylabel("Quantiles (Z-Scores)")
ax.set_title("Normality Plot (8.39a)")
ax.grid(True, linestyle=":", alpha=0.6)
# ax.legend()

plt.tight_layout()
# plt.show()
plt.savefig("opg8.39a.png")

# %% [markdown]
# # Opgave 9.130b

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

data = [220,225,297, 315, 282, 313]

# Calculate theoretical quantiles and sorted values without auto-plotting
(z_scores, values), (slope, intercept, _) = stats.probplot(data, dist="norm")

# Create plot with values on X and z-scores on Y
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(values, z_scores, color="blue", edgecolors="k", label="Data Points")

# Recalculate reference line equation for inverted axes
fit_line_y = (values - intercept) / slope
ax.plot(values, fit_line_y, color="red", linestyle="--", label="Fit Line")

ax.set_xlabel("Values")
ax.set_ylabel("Quantiles (Z-Scores)")
ax.set_title("Normality Plot (9.130b)")
ax.grid(True, linestyle=":", alpha=0.6)
# ax.legend()

plt.tight_layout()
# plt.show()
plt.savefig("opg9.130b.png")

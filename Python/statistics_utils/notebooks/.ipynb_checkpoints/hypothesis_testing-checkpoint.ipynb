# %%
import sys
sys.path.append("..")

from utils import *

# %% [markdown]
# # Hypothesetoetsen

# %% [markdown]
# ## Toetsen voor het gemiddelde $\mu$

# %%
def determine_critical_values_normal(test_type, mu_0, sample_std, alpha, xmin, xmax):
    if test_type == "tweezijdig":
        # Kritieke waarde onder H0 (voor tweezijdige toets)
        z_alpha = norm.ppf(1 - alpha / 2)
        critical_value_left = mu_0 - z_alpha * sample_std
        critical_value_right = mu_0 + z_alpha * sample_std
    elif test_type == "linkszijdig":
        # Kritieke waarde onder H0 (voor linkszijdige toets)
        z_alpha = norm.ppf(1 - alpha)
        critical_value_left = mu_0 - z_alpha * sample_std
        critical_value_right = xmax
    else:
        # Kritieke waarde onder H0 (voor rechtszijdige toets)
        z_alpha = norm.ppf(1 - alpha)
        critical_value_left = xmin
        critical_value_right = mu_0 + z_alpha * sample_std
    return critical_value_left, critical_value_right
    
def plot_hypothesis_testing_normal(test_type="tweezijdig", mu_0=0, mu_1=None, sigma=1, alpha=0.05, sample_size=30, test_stat=None, width=12, height=7.5, filename="test.txt"):
    fig, ax = plt.subplots(figsize=(width, height))
    sample_std = sigma / np.sqrt(sample_size)

    if mu_1:
        maxmu = max(mu_0, mu_1)
        minmu = min(mu_0, mu_1)
    else:
        maxmu, minmu = mu_0, mu_0
    x = np.linspace(minmu - 4 * sample_std, maxmu + 4 * sample_std, 1_000)   

    # H_0 specifics
    pdf_H0 = norm.pdf(x, mu_0, sample_std)

    # H1 specifics
    if mu_1:
        pdf_H1 = norm.pdf(x, mu_1, sample_std)

    # Draw horizontal lines indicating the regions
    xmin, xmax = x[0], x[-1]

    ax.set_xlabel('Toetsingsgrootheid $\\overline{x}$')
    ax.set_ylabel('Kansdichtheidsfunctie $f(\\overline{x})$')
    
    # Plot instellen
    ax.plot(x, pdf_H0, color=primary_plot_color, alpha=opacity_level)
    ax.plot([mu_0, mu_0], [0, norm.pdf(mu_0, mu_0, sample_std)], color=primary_plot_color, linestyle='--')

    ymin, ymax = ax.get_ylim()
    ytext, offset = get_y_annotation(ax)
    ymu = 1/4 * ytext
    ylines = 1/2 * ytext
    ax.set_ylim(ymin - 2 * offset, ymax)

    ax.text(mu_0, ymu, "$\\mu_0$", color=primary_plot_color, ha="center", va="center")

    if mu_1:
        ax.plot(x, pdf_H1, color=secondary_plot_color, alpha=opacity_level)
        ax.plot([mu_1, mu_1], [0, norm.pdf(mu_1, mu_1, sample_std)], color=secondary_plot_color, linestyle='--')
        ax.text(mu_1, ymu, "$\\mu_1$", color=secondary_plot_color, ha="center", va="center")

    # Determine the critical values
    critical_value_left, critical_value_right = determine_critical_values_normal(test_type, mu_0, sample_std, alpha, xmin, xmax)

    # Shade the critical region
    if critical_value_left != xmin:
        ax.plot([critical_value_left, critical_value_left], [0, norm.pdf(critical_value_left, mu_0, sample_std)], color=critical_color, linestyle='-')#, label='Kritieke grens links')
        ax.fill_between(x, 0, pdf_H0, where=(x < critical_value_left), color=critical_color, alpha=opacity_level, label=f'Type-I fout ($\\alpha$): {pretty_print(alpha)}')
    if critical_value_right != xmax:
        ax.plot([critical_value_right, critical_value_right], [0, norm.pdf(critical_value_right, mu_0, sample_std)], color=critical_color, linestyle='-')#, label='Kritieke grens rechts')
        ax.fill_between(x, 0, pdf_H0, where=(x > critical_value_right), color=critical_color, alpha=opacity_level)

    # Bereken de type-II fout en arceer de bijbehorende oppervlaktes (wat is de kans op een waarde in het acceptatiegebied?)
    if mu_1:
        beta = norm.cdf(critical_value_right, loc=mu_1, scale=sample_std) - norm.cdf(critical_value_left, loc=mu_1, scale=sample_std)
        ax.fill_between(x, 0, pdf_H1, where=((x < critical_value_right) & (x > critical_value_left)), color=secondary_plot_color, alpha=opacity_level, label=f'Type II fout ($\\beta$): {beta:.3f}')

    if test_type == "tweezijdig":
        label_critical_region = f"Kritiek gebied: $(-\\infty, {pretty_print(critical_value_left)}]$ en $[{pretty_print(critical_value_right)}, \\infty)$"        
        plt.suptitle(f'$H_0$: $\\mu={mu_0}$ vs. $H_1$: $\\mu \\neq {mu_0}$ (tweezijdige hypothesetoets)', fontsize=20)
        
    elif test_type == "rechtszijdig":
        label_critical_region = f"Kritiek gebied: $[{pretty_print(critical_value_right)}, \\infty)$"               
        plt.suptitle(f'$H_0$: $\\mu\\leq{mu_0}$ vs. $H_1$: $\\mu > {mu_0}$ (rechtszijdige hypothesetoets)', fontsize=20)
        
    else: # linkszijdig
        label_critical_region = f"Kritiek gebied: $(-\\infty, {pretty_print(critical_value_left)}]$"        
        plt.suptitle(f'$H_0$: $\\mu\\geq{mu_0}$ vs. $H_1$: $\\mu < {mu_0}$ (linkszijdige hypothesetoets)', fontsize=20)

    # Teken het acceptatiegebied
    ax.hlines(ylines, critical_value_left, critical_value_right, color=acceptable_color, linewidth=5)
    ax.text((critical_value_left + critical_value_right) / 2, ytext, 'Accepteer $H_0$', color=acceptable_color, fontsize=11, ha='center')
    
    # Teken het kritieke gebied
    if critical_value_left != xmin:
        ax.hlines(ylines, xmin, critical_value_left, color=critical_color, linewidth=5, label=label_critical_region)
        ax.text((critical_value_left + xmin) / 2, ytext, 'Verwerp $H_0$', color=critical_color, fontsize=11, ha='center')
    if critical_value_right != xmax:
        ax.hlines(ylines, critical_value_right, xmax, color=critical_color, linewidth=5)
        ax.text((critical_value_right + xmax) / 2, ytext, 'Verwerp $H_0$', color=critical_color, fontsize=11, ha='center')
    
    ax.set_title(f"Kansverdeling van de toetsingsgrootheid $\\overline{{X}}$ onder $H_0$: normale verdeling met $\\mu={mu_0}$ en $\\sigma = {sigma} / \\sqrt{{{sample_size}}}$")
    
    if test_stat:
        ax.plot([test_stat, test_stat], [0, norm.pdf(test_stat, mu_0, sample_std)], color=primary_plot_color, linestyle="--")

        test_stat_color = critical_color if test_stat < critical_value_left or test_stat > critical_value_right else acceptable_color
        ax.text(test_stat, ytext, '$\\overline{x}$', color=test_stat_color, fontsize=11, ha='center')

    ax.legend()
    plt.savefig(filename)

# %% [markdown]
# ### Voorbeeld gebruik

# %%
# Opgave 9.5
plot_hypothesis_testing_normal(test_type="linkszijdig", mu_0=42, mu_1=None, sigma=5, alpha=0.05, sample_size=50, test_stat=37.8, filename=FIGURE_PATH + "opg_9.5.png")

# Opgave 9.7
plot_hypothesis_testing_normal(test_type="tweezijdig", mu_0=5.0, mu_1=None, sigma=0.15, alpha=0.01, sample_size=25, test_stat=4.70, filename=FIGURE_PATH + "opg_9.7.png")

# Opgave 9.11
plot_hypothesis_testing_normal(test_type="linkszijdig", mu_0=160, mu_1=None, sigma=5, alpha=0.05, sample_size=6, test_stat=150, filename=FIGURE_PATH + "opg_9.11.png")
plot_hypothesis_testing_normal(test_type="rechtszijdig", mu_0=7.0, mu_1=7.30, sigma=0.5, alpha=0.05, sample_size=16, test_stat=None, filename=FIGURE_PATH + "test_hypothesis_4.png")

plot_hypothesis_testing_normal(test_type="linkszijdig", mu_0=65, sigma=0.7792, alpha=0.05, sample_size=10, test_stat=None, filename=FIGURE_PATH + "test_hypothesis_5.png")

plot_hypothesis_testing_normal(test_type="linkszijdig", mu_0=0, mu_1=None, sigma=1, alpha=0.05, sample_size=1, test_stat=None, width=10, height=7, filename=FIGURE_PATH + "left_sided.png")
plot_hypothesis_testing_normal(test_type="tweezijdig", mu_0=0, mu_1=None, sigma=1, alpha=0.05, sample_size=1, test_stat=None, width=10, height=7, filename=FIGURE_PATH + "two_sided.png")
plot_hypothesis_testing_normal(test_type="rechtszijdig", mu_0=0, mu_1=None, sigma=1, alpha=0.05, sample_size=1, test_stat=None, width=10, height=7, filename=FIGURE_PATH + "right_sided.png")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14744\1317041194.py:108: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# # Hypothesetoets met de $t$-verdeling

# %%
def determine_xrange_t_dist(df):
    if df == 1:
        return -10, 10
    elif df <= 5:
        return -6, 6
    elif df <= 30:
        return -5, 5
    else:
        return -4, 4

def determine_critical_values_normal(test_type, mu_0, sample_std, sample_size, alpha, xmin, xmax):
    if test_type == "tweezijdig":
        # Kritieke waarde onder H0 (voor tweezijdige toets)
        t_alpha = t.ppf(q=1-alpha/2, df=df)
        critical_value_left = -t_alpha
        critical_value_right = t_alpha
    elif test_type == "linkszijdig":
        # Kritieke waarde onder H0 (voor linkszijdige toets)
        t_alpha = t.ppf(q=alpha, df=df)
        critical_value_left = t_alpha
        critical_value_right = xmax
    else:
        # Kritieke waarde onder H0 (voor rechtszijdige toets)
        t_alpha = t.ppf(q=1-alpha, df=df)
        critical_value_left = xmin
        critical_value_right = t_alpha
    return critical_value_left, critical_value_right
    
def plot_hypothesis_testing_t(test_type="tweezijdig", mu_0=0, mu_1=None, sigma=1, alpha=0.05, sample_size=30, test_stat=None, width=12, height=7.5, filename="test.txt"):
    fig, ax = plt.subplots(figsize=(width, height))
    sample_std = sigma / np.sqrt(sample_size)

    df = sample_size - 1
    xmin, xmax = determine_xrange_t_dist(df)
    x = np.linspace(xmin, xmax, 1_000)   

    # H_0 specifics
    pdf_H0 = t.pdf(x, df=df, loc=mu_0, scale=sample_std)

    # H1 specifics
    if mu_1:
        pdf_H1 = t.pdf(x, df=df, loc=mu_1, scale=sample_std)

    # Draw horizontal lines indicating the regions
    xmin, xmax = x[0], x[-1]

    ax.set_xlabel('Toetsingsgrootheid $t = \\frac{{\\overline{x} - \\mu}}{{s/\\sqrt{{n}}}}$')
    ax.set_ylabel('Kansdichtheidsfunctie $f(t)$')
    
    # Plot instellen
    ax.plot(x, pdf_H0, color=primary_plot_color, alpha=opacity_level)
    ax.plot([mu_0, mu_0], [0, t.pdf(mu_0, df=df, mu_0, sample_std)], color=primary_plot_color, linestyle='--')

    ymin, ymax = ax.get_ylim()
    ytext, offset = get_y_annotation(ax)
    ymu = 1/4 * ytext
    ylines = 1/2 * ytext
    ax.set_ylim(ymin - 2 * offset, ymax)

    ax.text(mu_0, ymu, "$\\mu_0$", color=primary_plot_color, ha="center", va="center")

    if mu_1:
        ax.plot(x, pdf_H1, color=secondary_plot_color, alpha=opacity_level)
        ax.plot([mu_1, mu_1], [0, t.pdf(mu_1, df=df, mu_1, sample_std)], color=secondary_plot_color, linestyle='--')
        ax.text(mu_1, ymu, "$\\mu_1$", color=secondary_plot_color, ha="center", va="center")

    # Determine the critical values
    critical_value_left, critical_value_right = determine_critical_values_t(test_type, mu_0, sample_std, alpha, xmin, xmax)

    # Shade the critical region
    if critical_value_left != xmin:
        ax.plot([critical_value_left, critical_value_left], [0, t.pdf(critical_value_left, df=df, mu_0, sample_std)], color=critical_color, linestyle='-')#, label='Kritieke grens links')
        ax.fill_between(x, 0, pdf_H0, where=(x < critical_value_left), color=critical_color, alpha=opacity_level, label=f'Type-I fout ($\\alpha$): {pretty_print(alpha)}')
    if critical_value_right != xmax:
        ax.plot([critical_value_right, critical_value_right], [0, t.pdf(critical_value_right, df=df, mu_0, sample_std)], color=critical_color, linestyle='-')#, label='Kritieke grens rechts')
        ax.fill_between(x, 0, pdf_H0, where=(x > critical_value_right), color=critical_color, alpha=opacity_level)

    # Bereken de type-II fout en arceer de bijbehorende oppervlaktes (wat is de kans op een waarde in het acceptatiegebied?)
    if mu_1:
        beta = t.cdf(critical_value_right, df=df, loc=mu_1, scale=sample_std) - t.cdf(critical_value_left, df=df, loc=mu_1, scale=sample_std)
        ax.fill_between(x, 0, pdf_H1, where=((x < critical_value_right) & (x > critical_value_left)), color=secondary_plot_color, alpha=opacity_level, label=f'Type II fout ($\\beta$): {beta:.3f}')

    if test_type == "tweezijdig":
        label_critical_region = f"Kritiek gebied: $(-\\infty, {pretty_print(critical_value_left)}]$ en $[{pretty_print(critical_value_right)}, \\infty)$"        
        plt.suptitle(f'$H_0$: $\\mu={mu_0}$ vs. $H_1$: $\\mu \\neq {mu_0}$ (tweezijdige hypothesetoets)', fontsize=20)
        
    elif test_type == "rechtszijdig":
        label_critical_region = f"Kritiek gebied: $[{pretty_print(critical_value_right)}, \\infty)$"               
        plt.suptitle(f'$H_0$: $\\mu\\leq{mu_0}$ vs. $H_1$: $\\mu > {mu_0}$ (rechtszijdige hypothesetoets)', fontsize=20)
        
    else: # linkszijdig
        label_critical_region = f"Kritiek gebied: $(-\\infty, {pretty_print(critical_value_left)}]$"        
        plt.suptitle(f'$H_0$: $\\mu\\geq{mu_0}$ vs. $H_1$: $\\mu < {mu_0}$ (linkszijdige hypothesetoets)', fontsize=20)

    # Teken het acceptatiegebied
    ax.hlines(ylines, critical_value_left, critical_value_right, color=acceptable_color, linewidth=5)
    ax.text((critical_value_left + critical_value_right) / 2, ytext, 'Accepteer $H_0$', color=acceptable_color, fontsize=11, ha='center')
    
    # Teken het kritieke gebied
    if critical_value_left != xmin:
        ax.hlines(ylines, xmin, critical_value_left, color=critical_color, linewidth=5, label=label_critical_region)
        ax.text((critical_value_left + xmin) / 2, ytext, 'Verwerp $H_0$', color=critical_color, fontsize=11, ha='center')
    if critical_value_right != xmax:
        ax.hlines(ylines, critical_value_right, xmax, color=critical_color, linewidth=5)
        ax.text((critical_value_right + xmax) / 2, ytext, 'Verwerp $H_0$', color=critical_color, fontsize=11, ha='center')
    
    ax.set_title(f"Kansverdeling van de toetsingsgrootheid $\\overline{{X}}$ onder $H_0$: normale verdeling met $\\mu={mu_0}$ en $\\sigma = {sigma} / \\sqrt{{{sample_size}}}$")
    
    if test_stat:
        ax.plot([test_stat, test_stat], [0, t.pdf(test_stat, df=df, mu_0, sample_std)], color=primary_plot_color, linestyle="--")

        test_stat_color = critical_color if test_stat < critical_value_left or test_stat > critical_value_right else acceptable_color
        ax.text(test_stat, ytext, '$t$', color=test_stat_color, fontsize=11, ha='center')

    ax.legend()
    plt.savefig(filename)
# Out:
#   Cell In[70], line 14
#     t_alpha = t.ppf(df=sample_size-1, 1 - alpha / 2)
#                                                    ^
# SyntaxError: positional argument follows keyword argument

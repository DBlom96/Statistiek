# %%
data1 = [72, 51, 146, 30, 28, 88, 92, 47, 52, 68, 80, 34, 28, 105, 76, 93, 55, 40, 62, 37, 88, 30, 122, 46, 35, 29, 77, 40, 71, 57]
data2 = [88, 130, 255, 56, 0, 38, 167, 188, 132, 147, 78, 80, 40, 170, 280, 46, 174, 182, 75, 89, 103, 230, 380, 57, 55, 90, 96, 102, 78, 69, 53, 160, 195, 245, 60, 94, 145, 115, 225, 71]

# %%
import numpy as np
print(sorted(data1))
print(sorted(data2))
np.mean(data1), np.median(data1)
# Out:
# [28, 28, 29, 30, 30, 34, 35, 37, 40, 40, 46, 47, 51, 52, 55, 57, 62, 68, 71, 72, 76, 77, 80, 88, 88, 92, 93, 105, 122, 146] [0, 38, 40, 46, 53, 55, 56, 57, 60, 69, 71, 75, 78, 78, 80, 88, 89, 90, 94, 96, 102, 103, 115, 130, 132, 145, 147, 160, 167, 170, 174, 182, 188, 195, 225, 230, 245, 255, 280, 380]
# (62.63333333333333, 56.0)

# %%
import matplotlib.pyplot as plt
plt.boxplot([data1, data2], tick_labels=["Studenten", "Afgestudeerden"])
plt.grid(axis="y", alpha=0.5)
plt.ylabel("Maandelijkse uitgaven (in euro)")
plt.title("Maandelijkse uitgaven aan uiteten")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma, weibull_min, uniform

colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
print(colors)
# blue, orange, green, red, purple, brown, pink, grey, olive, cyan
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# # Probability density function

# %%
fig, ax = plt.subplots()

# x-axis
x = np.linspace(0, 15, 1_000)
y = 0.5 * np.exp(-0.5 * x)

ax.plot(x, y, color=colors[0])

ax.set_xlabel("$x$")
ax.set_ylabel("Kansdichtheidsfunctie $f(x)$")
ax.set_title('Kansdichtheidsfunctie (PDF) van "time-to-detection"')
ax.grid(True, alpha=0.3)
plt.savefig("./Figures/3_example_pdf.png")

# %% [markdown]
# # Hoe bereken je kansen voor continue kansvariabelen?

# %%
fig, ax = plt.subplots()

# x-axis
x = np.linspace(0, 15, 1_000)
y = 0.5 * np.exp(-0.5 * x)

ax.plot(x, y, color=colors[0])
ax.fill_between(x, y, where=((x>=2)&(x<=5)), ec=colors[0], color=colors[0], alpha=0.3)

ax.set_xlabel("$x$")
ax.set_ylabel("Kansdichtheidsfunctie $f(x)$")
ax.set_title('Kansdichtheidsfunctie van de "time-to-detection"')
ax.grid(True, alpha=0.3)
plt.savefig("./Figures/3_cont_prob.png")

# %%
fig, ax = plt.subplots()

# x-axis
x = np.linspace(-5, 10, 1_000)

# Plot of function f(x) = 1/6 for 0 <= x <= 5, and 0 otherwise. This is NOT a pdf!
ax.plot([-5, 1], [0, 0], color=colors[0])
ax.plot([1, 8], [1/6, 1/6], color=colors[0])
ax.plot([8, 10], [0, 0], color=colors[0])

ax.plot([1, 1], [0, 1/6], color=colors[0], linestyle="dashed")
ax.plot([8, 8], [0, 1/6], color=colors[0], linestyle="dashed")

ax.set_xlabel("$x$")
ax.set_ylabel("$f(x)$")
ax.set_title('Functie $f(x)$')
ax.grid(True, alpha=0.3)

plt.savefig("./Figures/3_example_not_pdf.png")

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

TARGET = 6.1

# x-axis
x = np.linspace(0, 12, 1_000)

mask = ((x>1)&(x<8))
y_pdf = uniform.pdf(x, loc=1, scale=7)
# y_pdf = weibull_min.pdf(x, c=2.1, scale=4)
axes[0].plot(x, y_pdf, color=colors[0])
axes[0].fill_between(x, y_pdf, where=((x>=0)&(x<=6.1)), ec=colors[0], color=colors[0], alpha=0.3)

axes[0].annotate("Oppervlakte $=$ lengte $\\times$ breedte \n= $(6.1 - 1) \\cdot \\frac{1}{7}$ \n$\\approx 0.7286$.", xy=(3.5, 0.08), xytext=(1.25, 0.08),
arrowprops=None)


axes[0].set_xlabel("$x$")
axes[0].set_ylabel("Kansdichtheidsfunctie $f(x)$")
axes[0].set_title('Cumulatieve verdelingsfunctie $F(x)$ als integraal', fontsize=18)
axes[0].set_xticks(np.arange(0, 13, 1))
axes[0].grid(True, alpha=0.3)


y_cdf = uniform.cdf(x, loc=1, scale=7) 
# y_cdf = weibull_min.cdf(x, c=2.1, scale=4)
axes[1].plot(x, y_cdf, color=colors[0])

axes[1].scatter([TARGET], [uniform.cdf(TARGET, loc=1, scale=7)])
axes[1].plot([TARGET, TARGET, 0], [0, uniform.cdf(TARGET, loc=1, scale=7), uniform.cdf(TARGET, loc=1, scale=7)], linestyle="dashed")


axes[1].set_xlabel("$x$")
axes[1].set_ylabel("Cumulatieve verdelingsfunctie $F(x)$")
axes[1].set_title('Plot van de cumulatieve verdelingsfunctie $F(x)$', fontsize=18)
axes[1].set_xticks(np.arange(0, 13, 1))
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("./Figures/3_cumulative_distribution_function.png")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# x-axis
x = np.linspace(0, 10, 1_000)
# y = 0.003 * (10 - x) ** 2
y = 0.5 * np.exp(-0.5 * x)

axes[0].plot(x, y, color=colors[0])
axes[0].set_xlabel("$x$")
axes[0].set_ylabel("Kansdichtheidsfunctie $f(x)$")
# axes[0].set_title('Plot van $f(x) = 0.003 \\cdot (10 - x)^2$', fontsize=14)
axes[0].set_title('Plot van $f(x) = 0.5 \\cdot e^{-0.5x}$', fontsize=14)
axes[0].set_xticks(np.arange(0, 11, 1))
axes[0].grid(True, alpha=0.3)

axes[1].plot(x, y, color=colors[0])
axes[1].fill_between(x, y, where=((x>=3)&(x<=10)), ec=colors[0], alpha=0.3)
axes[1].set_xlabel("$x$")
axes[1].set_ylabel("Kansdichtheidsfunctie $f(x)$")
axes[1].set_title('Kans op geen detectie voor meer dan 3 seconden', fontsize=14)
axes[1].set_xticks(np.arange(0, 11, 1))
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("./Figures/3_example_exercise.png")

# %% [markdown]
# # Opgave 4.15b

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

TARGET = 7

def pdf(x):
    if 5 <= x <= 10:
        return 0.2
    return 0
    
def cdf(x):
    if x < 5:
        return 0
    elif x <= 10:
        return 0.2 * (x - 5)
    else:
        return 1

# Maak een vector voor het plotten
xs = np.linspace(0, 12, 1_000)
fs = [pdf(x) for x in xs]
Fs = [cdf(x) for x in xs]
    
axes[0].plot(x, fs, color=colors[0])
axes[0].fill_between(x, fs, where=((x>=0)&(x<=TARGET)), ec=colors[0], color=colors[0], alpha=0.3)

axes[0].set_xlabel("$x$")
axes[0].set_ylabel("Kansdichtheidsfunctie $f(x)$")
axes[0].set_title('Cumulatieve verdelingsfunctie $F(x)$ als integraal', fontsize=18)
axes[0].set_xticks(np.arange(0, 13, 1))
axes[0].grid(True, alpha=0.3)

axes[1].plot(x, Fs, color=colors[0])

axes[1].scatter([TARGET], [cdf(TARGET)])
axes[1].plot([TARGET, TARGET, 0], [0, cdf(TARGET), cdf(TARGET)], linestyle="dashed")

axes[1].set_xlabel("$x$")
axes[1].set_ylabel("Cumulatieve verdelingsfunctie $F(x)$")
axes[1].set_title('Cumulatieve verdelingsfunctie $F(x)$ als grafiek', fontsize=18)
axes[1].set_xticks(np.arange(0, 13, 1))
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("./Figures/opg4.15b.png")

# %% [markdown]
# # Opgave 4.17

# %%
fig, ax = plt.subplots(figsize=(16, 5))

def pdf(x):
    if 3 <= x < 4:
        return 0.4
    elif 4 <= x < 5:
        return 0.6
    else:
        return 0

# Maak een vector voor het plotten
xs = np.linspace(2, 6, 1_000)
fs = [pdf(x) for x in xs]
    
ax.plot(xs, fs, color=colors[0])
ax.fill_between(xs, fs, where=((xs>=10/3)&(xs<=4)), ec=colors[0], color=colors[0], alpha=0.3)
ax.fill_between(xs, fs, where=((xs>=4)&(xs<=13/3)), ec=colors[1], color=colors[1], alpha=0.3)

ax.set_xlabel("$x$")
ax.set_ylabel("Kansdichtheidsfunctie $f(x)$")
ax.set_title('Cumulatieve verdelingsfunctie $F(x)$ als integraal', fontsize=18)
ax.set_xticks(np.arange(2, 7, 1))
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("./Figures/opg4.17.png")

# %%
from scipy.stats import norm
np.random.seed(42)  # For reproducibility

x = np.linspace(0, 100, 100_000)

mu, sigma = 65, 10
samples = np.random.normal(mu, sigma, 1000000)

fig, axes = plt.subplots(1, 3, figsize=(25,8))

axes[0].hist(samples, bins=np.arange(0, 101, 10), density=True)
axes[0].set_title("Histogram met klassenbreedte $10$", fontsize=20)

axes[1].hist(samples, bins=np.arange(0, 101, 5), density=True)
axes[1].set_title("Histogram met klassenbreedte $1$", fontsize=20)

axes[2].hist(samples, bins=np.arange(0, 101, 0.1), density=True)
axes[2].set_title("Histogram met klassenbreedte $0.1$", fontsize=20)

for i in range(3):
    axes.set_xlabel("Schietscore (%)", fontsize=15)
    axes.set_ylabel("Dichtheid", fontsize=15)
    axes.tick_params(labelsize=15)
    
plt.savefig("./Figures/3_from_data_to_pdf.png")

fig, axes = plt.subplots(1, 2, figsize=(25,8))

axes[0].hist(samples, bins=np.arange(0, 101, 0.1), density=True)
axes[0].set_title("Histogram met klassenbreedte $0.1$", fontsize=20)


axes[1].plot(x, norm.pdf(x, mu, sigma))
axes[1].set_title("Kansdichtheidsfunctie van schietscore (%)", fontsize=20)


axes[0].set_ylabel("Relatieve frequentie", fontsize=15)
axes[1].set_ylabel("Kansdichtheid $f(x)$", fontsize=15)

for i in range(2):
    axes.set_ylim(-0.001, 0.05)
    axes.set_xlabel("Schietscore (%)", fontsize=15)
    axes.tick_params(labelsize=15)


plt.savefig("./Figures/3_from_hist_to_pdf.png")

# %%
fig, axes = plt.subplots(1, 2, figsize=(25,8))

pdf = norm.pdf(x, mu, sigma)
axes[0].plot(x, pdf)
axes[0].set_title("Kansdichtheidsfunctie van schietscore (%)", fontsize=20)

axes[1].plot(x, pdf)
axes[1].fill_between(x, pdf, 0, where=((x>75)&(x<85)), alpha=0.4)
axes[1].set_ylabel("Relatieve frequentie", fontsize=15)
axes[1].set_title("Kans op schietscore tussen 75% en 85%", fontsize=20)


for i in range(2):
    axes.set_ylim(-0.001, 0.05)
    axes.set_xlabel("Schietscore (%)", fontsize=15)
    axes.set_ylabel("Kansdichtheid $f(x)$", fontsize=15)
    axes.tick_params(labelsize=15)


plt.savefig("./Figures/3_pdf_prob.png")

# %%
from scipy.stats import norm
np.random.seed(42)  # For reproducibility

x = np.linspace(0, 100, 100_000)

mu, sigma = 65, 10
samples = [85.3, 92.4, 78.1, 88.9, 65.3, 80.2, 90.1, 72.9, 70.3, 95.6, 82.1, 68.0, 88.7, 92.5, 60.2, 87.4, 75.7, 85.9, 80.1, 62.4]

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(25,8))

axes.hist(samples, bins=np.arange(0, 101, 10), density=True)
axes.set_title("Histogram met klassenbreedte $10$", fontsize=20)
axes.set_xlabel("Schietscore (%)", fontsize=15)
axes.set_ylabel("Dichtheid", fontsize=15)
axes.tick_params(labelsize=15) 
    
plt.savefig("./Figures/3_histogram_shooting_scores.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       7 samples = [85.3, 92.4, 78.1, 88.9, 65.3, 80.2, 90.1, 72.9, 70.3, 95.6, 82.1, 68.0, 88.7, 92.5, 60.2, 87.4, 75.7, 85.9, 80.1, 62.4]
#       9 fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(25,8))
# ---> 11 axes[0].hist(samples, bins=np.arange(0, 101, 10), density=True)
#      12 axes[0].set_title("Histogram met klassenbreedte $10$", fontsize=20)
#      14 for i in range(1):
#
# TypeError: 'Axes' object is not subscriptable
